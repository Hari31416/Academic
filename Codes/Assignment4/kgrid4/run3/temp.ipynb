# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("KS_DOS_total.dat")
plt.figure(figsize=(10,6))
plt.plot(data[:,0], data[:,1])
plt.title("Total DOS")
plt.xlabel("Energy (eV)")
plt.ylabel("DOS (states/eV)")
# Out:
# Text(0, 0.5, 'DOS (states/eV)')

# %%
data
# Out:
# array([[-13.63229401,   0.2374459 ,   0.2374459 ],
#        [-13.62829361,   0.2383887 ,   0.2383887 ],
#        [-13.62429321,   0.23928232,   0.23928232],
#        ...,
#        [ 26.35970519,   0.        ,   0.        ],
#        [ 26.36370559,   0.        ,   0.        ],
#        [ 26.36770599,   0.        ,   0.        ]])
