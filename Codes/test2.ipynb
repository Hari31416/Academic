# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
# <td style="border: none;">
# <a target="blank" href="https://colab.research.google.com/github/Hari31416/PYL800/blob/main/Codes/test2.ipynb?hl=en"><img src="https://colab.research.google.com/img/colab_favicon_256px.png" width="28" height="28"/>Run on Google Colab</a></td>
# <td style="border: none;">
# <a target="blank" href="https://github.com/Hari31416/PYL800/blob/main/Codes/test2.ipynb"><img src="https://cdn.icon-icons.com/icons2/2368/PNG/512/github_logo_icon_143772.png" width="28" height="28"/>View on Github</a></td>
# <td style="border: none;">
# <a target="blank" href="https://mybinder.org/v2/gh/Hari31416/PYL800/HEAD?filepath=Codes%2Ftest2.ipynb"><img src="https://static.mybinder.org/badge_logo.svg" alt="Launch on Binder"></a></td>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.linspace(-5,5, 200)
y = np.exp(x)
plt.plot(x,y,"r")

# %%
x = np.linspace(-5,5, 200)
y = np.log(x)
plt.plot(x,y,"g")
# Out:
# <ipython-input-5-2ff95546b7d9>:2: RuntimeWarning: invalid value encountered in log
#   y = np.log(x)

# %% [markdown]
# Use the command `jupyter nbconvert --to webpdf --allow-chromium-download test2.ipynb` to convert the notebook to a pdf file using web version which is much better than the one used to convert the notebook to a pdf file using LaTeX.
